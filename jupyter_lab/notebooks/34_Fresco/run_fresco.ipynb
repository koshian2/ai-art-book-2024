# %%
# Setup GMFlow
# !git clone https://github.com/haofeixu/gmflow

# Also, Please edit run_fresco.py in line2 if you want to run another directory
# import sys
# gmflow_dir = "/home/34_Fresco/gmflow" ###  <- Please edit this path
# sys.path.insert(0, gmflow_dir)
# Out:
# Cloning into 'gmflow'...
# remote: Enumerating objects: 122, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 122 (delta 26), reused 22 (delta 21), pack-reused 77
# Receiving objects: 100% (122/122), 4.41 MiB | 12.27 MiB/s, done.
# Resolving deltas: 100% (40/40), done.

# %%
# !python run_fresco.py \
    --input_video_path train_view.mp4 \
    --output_video_base_path generated/train_view_mountain \
    --base_sd15_model_name sinkinai/anime-pastel-dream-soft-baked-vae \
    --prompt 'a train is running, view from the window, amazing mountain scenery' \
    --negative_prompt '(deformed iris, deformed pupils, semi-realistic, cgi, 3d, render, sketch, mutated hands and fingers:1.4), (deformed, distorted, disfigured:1.3), poorly drawn, bad anatomy, wrong anatomy, extra limb, missing limb, floating limbs, disconnected limbs, mutation, mutated, ugly, disgusting, amputation' \
    --controlnet_name soft_edge \
    --input_interval 8 --width 512 --height 288 --save_frames
# Out:
# /usr/local/lib/python3.10/dist-packages/controlnet_aux/mediapipe_face/mediapipe_face_common.py:7: UserWarning: The module 'mediapipe' is not installed. The package will have limited functionality. Please install it using the command: pip install 'mediapipe'
#   warnings.warn(
# Frames len :  59
# /usr/local/lib/python3.10/dist-packages/controlnet_aux/pidi/model.py:334: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:78.)
#   buffer = torch.cuda.FloatTensor(shape[0], shape[1], 5 * 5).fill_(0)
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
# ...

# %%
# !python run_fresco.py \
    --input_video_path train_view.mp4 \
    --output_video_base_path generated/train_view_galaxy \
    --base_sd15_model_name stablediffusionapi/rev-animated \
    --prompt 'A train is running through galaxy space. view from the window. beautiful milky way.' \
    --negative_prompt '(deformed iris, deformed pupils, semi-realistic, cgi, render, sketch, mutated hands and fingers:1.4), (deformed, distorted, disfigured:1.3), poorly drawn, bad anatomy, wrong anatomy, extra limb, missing limb, floating limbs, disconnected limbs, mutation, mutated, ugly, disgusting, amputation' \
    --controlnet_name depth \
    --input_interval 8 --width 512 --height 288 --controlnet_weight 0.3 --save_frames
# Out:
# /usr/local/lib/python3.10/dist-packages/controlnet_aux/mediapipe_face/mediapipe_face_common.py:7: UserWarning: The module 'mediapipe' is not installed. The package will have limited functionality. Please install it using the command: pip install 'mediapipe'
#   warnings.warn(
# Frames len :  59
# 59 (512, 288) 59 (512, 288)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:671: FutureWarning: 'cached_download' is the legacy way to download files from the HF hub, please consider upgrading to 'hf_hub_download'
#   warnings.warn(
# text_encoder/model.safetensors not found
# ...
# scheduler/scheduler_config.json: 100%|█████████| 460/460 [00:00<00:00, 4.72MB/s]
#
# tokenizer/special_tokens_map.json: 100%|███████| 472/472 [00:00<00:00, 4.36MB/s]
#
# (…)ature_extractor/preprocessor_config.json: 100%|█| 520/520 [00:00<00:00, 5.51M
# ...
# text_encoder/config.json: 100%|████████████████| 612/612 [00:00<00:00, 6.31MB/s]
#
# ...

# %%
# !python run_fresco.py \
    --input_video_path hippop.mp4 \
    --output_video_base_path generated/hippop1 \
    --base_sd15_model_name stablediffusionapi/flat-2d-animerge \
    --prompt 'a girl is dancing hippop, purple haired' \
    --negative_prompt '(deformed iris, deformed pupils, semi-realistic, cgi, 3d, render, sketch, mutated hands and fingers:1.4), (deformed, distorted, disfigured:1.3), poorly drawn, bad anatomy, wrong anatomy, extra limb, missing limb, floating limbs, disconnected limbs, mutation, mutated, ugly, disgusting, amputation' \
    --controlnet_name pose \
    --input_interval 12 --width 512 --height 512 --save_frames
# Out:
# /usr/local/lib/python3.10/dist-packages/controlnet_aux/mediapipe_face/mediapipe_face_common.py:7: UserWarning: The module 'mediapipe' is not installed. The package will have limited functionality. Please install it using the command: pip install 'mediapipe'
#   warnings.warn(
# Frames len :  20
# 20 (512, 512) 20 (512, 512)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:671: FutureWarning: 'cached_download' is the legacy way to download files from the HF hub, please consider upgrading to 'hf_hub_download'
#   warnings.warn(
# vae/diffusion_pytorch_model.safetensors not found
# ...
# text_encoder/config.json: 100%|████████████████| 560/560 [00:00<00:00, 5.19MB/s]
#
# tokenizer/special_tokens_map.json: 100%|███████| 472/472 [00:00<00:00, 6.13MB/s]
#
# (…)ature_extractor/preprocessor_config.json: 100%|█| 520/520 [00:00<00:00, 5.82M
# ...
# scheduler/scheduler_config.json: 100%|█████████| 379/379 [00:00<00:00, 4.04MB/s]
#
# ...

# %%
# !python run_fresco.py \
    --input_video_path hippop.mp4 \
    --output_video_base_path generated/hippop2 \
    --base_sd15_model_name JosephusCheung/ACertainThing \
    --prompt 'a girl is dancing hippop, 1girl, brown hair, green eyes, autumn mountain' \
    --negative_prompt "longbody, lowres, bad anatomy, bad hands, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality" \
    --controlnet_name pose \
    --input_interval 12 --width 512 --height 512 --strength 0.9 --save_frames
# Out:
# /usr/local/lib/python3.10/dist-packages/controlnet_aux/mediapipe_face/mediapipe_face_common.py:7: UserWarning: The module 'mediapipe' is not installed. The package will have limited functionality. Please install it using the command: pip install 'mediapipe'
#   warnings.warn(
# Frames len :  20
# 20 (512, 512) 20 (512, 512)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:671: FutureWarning: 'cached_download' is the legacy way to download files from the HF hub, please consider upgrading to 'hf_hub_download'
#   warnings.warn(
# vae/diffusion_pytorch_model.safetensors not found
# Fetching 13 files:   0%|                                 | 0/13 [00:00<?, ?it/s]
# (…)ature_extractor/preprocessor_config.json: 100%|█| 342/342 [00:00<00:00, 2.58M
#
# ...
# tokenizer/special_tokens_map.json: 100%|███████| 472/472 [00:00<00:00, 4.99MB/s]
#
# text_encoder/config.json: 100%|████████████████| 612/612 [00:00<00:00, 6.25MB/s]
#
# ...

# %%
# !python run_fresco.py \
    --input_video_path dog.mp4 \
    --output_video_base_path generated/dog \
    --base_sd15_model_name stablediffusionapi/rev-animated \
    --prompt 'T-Rex is running on a river side' \
    --negative_prompt '(deformed iris, deformed pupils, semi-realistic, cgi, 3d, render, sketch, mutated hands and fingers:1.4), (deformed, distorted, disfigured:1.3), poorly drawn, bad anatomy, wrong anatomy, extra limb, missing limb, floating limbs, disconnected limbs, mutation, mutated, ugly, disgusting, amputation' \
    --controlnet_name depth \
    --input_interval 10 --width 512 --height 384 --controlnet_weight 0.2 --save_frames
# Out:
# /usr/local/lib/python3.10/dist-packages/controlnet_aux/mediapipe_face/mediapipe_face_common.py:7: UserWarning: The module 'mediapipe' is not installed. The package will have limited functionality. Please install it using the command: pip install 'mediapipe'
#   warnings.warn(
# Frames len :  25
# 25 (512, 384) 25 (512, 384)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:671: FutureWarning: 'cached_download' is the legacy way to download files from the HF hub, please consider upgrading to 'hf_hub_download'
#   warnings.warn(
# unet/diffusion_pytorch_model.safetensors not found
# Loading pipeline components...:  17%|██▏          | 1/6 [00:04<00:22,  4.51s/it]/usr/local/lib/python3.10/dist-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# ...
